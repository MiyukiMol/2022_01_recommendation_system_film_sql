# %% [markdown]
# # Etude sur Développez un moteur de recommandation de films

# %% [markdown]
# Un site sur le cinéma vous contacte, car ils souhaitent lancer un moteur de recommandation de film pour sauver les soirées ciné de leurs futurs clients. Pour ce faire, vous devrez créer un moteur de recommandations de films. Le seul problème : il n'y a pas encore d’utilisateurs.

# %% [markdown]
# #### Contexte du projet

# %% [markdown]
# Votre client, vous communique une base de données publique d’informations sur des films, à défaut d'avoir des données sur leurs utilisateurs. https://www.dropbox.com/s/5779djv4tefh6vz/imdb-5000-movie-dataset%20%281%29.zip?dl=0
#
# À l’aide de méthodes non supervisées vous devrez élaborer un système capable de retourner 5 recommandations de films similaires et intéressants pour le visiteur. Ceci à partir d’un nom de film (ou un id).

# %% [markdown]
# #### Modalités pédagogiques

# %% [markdown]
# Travail individuel. Le travail implique de faire du traitement de texte et notamment pour le feature engineering. Pour cela voici des ressources pour monter en compétence :
#
# cours : https://www.dropbox.com/sh/jinhd7xyjq8gmxi/AAAXcjnfKGIB5gRBE3iI_3JPa?dl=0
#
# https://www.dropbox.com/sh/6p3eqo93l85oj67/AADI0DkLpKHAmPy_h4KksX5ja?dl=0
#
# ​
#
# exos : https://www.dropbox.com/sh/rgcc3mrs7hsvk5z/AAA4Rtcah1SKOqqUI3vgrsdGa?dl=0

# %% [markdown]
# #### Critères de performance

# %% [markdown]
#     Analyse exploratoire propre et commentée
#     Veille synthétique et claire
#     Choix de la démarche de modélisation pertinente
#     Sélection des variables de la base de modélisation pertinente
#     Tests de plusieurs algorithmes avec évaluation de la performance
#     Choix du modèle final justifié

# %% [markdown]
# ### 1 - import librarys

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors

# %% [markdown]
# ### 2 - set option pour l'affichage

# %%
pd.set_option("max_columns", None)
pd.set_option("max_colwidth", None)
pd.set_option("max_row", 500)

# %% [markdown]
# ### 3 - read dataset

# %%
df = pd.read_csv( "movie_metadata.csv")

# %%
df.head(1)
# Out:
#    color  director_name  num_critic_for_reviews  duration  \
# 0  Color  James Cameron                   723.0     178.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
#
#   actor_1_name movie_title  num_voted_users  cast_total_facebook_likes  \
# 0  CCH Pounder     Avatar            886204                       4834
#
#   actor_3_name  facenumber_in_poster                           plot_keywords  \
# 0    Wes Studi                   0.0  avatar|future|marine|native|paraplegic
#
#                                         movie_imdb_link  num_user_for_reviews  \
# 0  http://www.imdb.com/title/tt0499549/?ref_=fn_tt_tt_1                3054.0
#
#   language country content_rating       budget  title_year  \
# 0  English     USA          PG-13  237000000.0      2009.0
#
#    actor_2_facebook_likes  imdb_score  aspect_ratio  movie_facebook_likes
# 0                   936.0         7.9          1.78                 33000

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
#  13  cast_total_facebook_likes  5043 non-null   int64
#  14  actor_3_name               5020 non-null   object
#  15  facenumber_in_poster       5030 non-null   float64
#  16  plot_keywords              4890 non-null   object
#  17  movie_imdb_link            5043 non-null   object
#  18  num_user_for_reviews       5022 non-null   float64
#  19  language                   5031 non-null   object
#  20  country                    5038 non-null   object
#  21  content_rating             4740 non-null   object
#  22  budget                     4551 non-null   float64
#  23  title_year                 4935 non-null   float64
#  24  actor_2_facebook_likes     5030 non-null   float64
#  25  imdb_score                 5043 non-null   float64
#  26  aspect_ratio               4714 non-null   float64
#  27  movie_facebook_likes       5043 non-null   int64
# dtypes: float64(13), int64(3), object(12)
# memory usage: 1.1+ MB
# None

# %% [markdown]
# ### nettoyage des données

# %%
# make a copy of data set
df_cp = df.copy()

# %% [markdown]
# #### J'enlève "\xa0" après movie_title

# %%
df_cp['movie_title']=='Avatar\xa0'
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5038    False
# 5039    False
# 5040    False
# 5041    False
# 5042    False
# Name: movie_title, Length: 5043, dtype: bool

# %%
# remove all the space after titles
df_cp['movie_title'] = df_cp['movie_title'].str.strip(' ')

# %%
# \xa0 is actually non-breaking space in Latin1 (ISO 8859-1), also chr(160). You should replace it with a space.
df_cp['movie_title'] = df_cp['movie_title'].str[:-1]

# %%
df_cp['movie_title']=='Avatar\xa0'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5038    False
# 5039    False
# 5040    False
# 5041    False
# 5042    False
# Name: movie_title, Length: 5043, dtype: bool

# %% [markdown]
# #### J'enlève des mêmes titles de movies.

# %%
df_cp[df_cp['movie_title']=='Ben-Hur']
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 367   Color  Timur Bekmambetov                     1.0     141.0
# 2613  Color  Timur Bekmambetov                     1.0     141.0
# 3967  Color  Timur Bekmambetov                     1.0     141.0
#
#       director_facebook_likes  actor_3_facebook_likes  actor_2_name  \
# 367                     335.0                   635.0  Ayelet Zurer
# 2613                    335.0                   635.0  Ayelet Zurer
# 3967                    335.0                   635.0  Ayelet Zurer
#
#       actor_1_facebook_likes  gross                   genres    actor_1_name  \
# 367                  11000.0    NaN  Adventure|Drama|History  Morgan Freeman
# 2613                 11000.0    NaN  Adventure|Drama|History  Morgan Freeman
# 3967                 11000.0    NaN  Adventure|Drama|History  Morgan Freeman
#
#      movie_title  num_voted_users  cast_total_facebook_likes  actor_3_name  \
# 367      Ben-Hur               57                      13379  Moises Arias
# 2613     Ben-Hur               62                      13390  Moises Arias
# 3967     Ben-Hur               67                      13391  Moises Arias
#
#       facenumber_in_poster  \
# 367                    2.0
# 2613                   2.0
# 3967                   2.0
#
#                                            plot_keywords  \
# 367                                                  NaN
# 2613  chariot race|epic|false accusation|jerusalem|slave
# 3967  chariot race|epic|false accusation|jerusalem|slave
#
#                                            movie_imdb_link  \
# 367   http://www.imdb.com/title/tt2638144/?ref_=fn_tt_tt_1
# 2613  http://www.imdb.com/title/tt2638144/?ref_=fn_tt_tt_1
# 3967  http://www.imdb.com/title/tt2638144/?ref_=fn_tt_tt_1
#
#       num_user_for_reviews language country content_rating       budget  \
# 367                    1.0  English     USA          PG-13          NaN
# 2613                   1.0  English     USA          PG-13  100000000.0
# 3967                   1.0  English     USA          PG-13  100000000.0
#
#       title_year  actor_2_facebook_likes  imdb_score  aspect_ratio  \
# 367       2016.0                   745.0         6.1          2.35
# 2613      2016.0                   744.0         6.1          2.35
# 3967      2016.0                   744.0         6.0          2.35
#
#       movie_facebook_likes
# 367                      0
# 2613                     0
# 3967                     0

# %%
df_cp.movie_title.value_counts()
# Out:
# The Fast and the Furious    3
# Ben-Hur                     3
# Home                        3
# Victor Frankenstein         3
# King Kong                   3
#                            ..
# The Whole Ten Yards         1
# North Country               1
# 88 Minutes                  1
# Love & Other Drugs          1
# My Date with Drew           1
# Name: movie_title, Length: 4916, dtype: int64

# %%
# drop_duplicates() remove duplicates from the data frame
df_cp = df_cp.drop_duplicates(subset=['director_name','movie_title'],keep='last')

# %%
df_cp.movie_title.value_counts()
# Out:
# Out of the Blue                        2
# The Host                               2
# The Dead Zone                          2
# Avatar                                 1
# Held Up                                1
#                                       ..
# Trapped                                1
# Barney's Version                       1
# The Imaginarium of Doctor Parnassus    1
# An Unfinished Life                     1
# My Date with Drew                      1
# Name: movie_title, Length: 4916, dtype: int64

# %% [markdown]
# These 3 films have different director names, it means they are not identic.

# %%
df_cp[df_cp['movie_title']=='The Dead Zone']
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 2702  Color               NaN                    18.0      60.0
# 3130  Color  David Cronenberg                   112.0     103.0
#
#       director_facebook_likes  actor_3_facebook_likes    actor_2_name  \
# 2702                      NaN                   186.0  Nicole de Boer
# 3130                      0.0                   275.0     Herbert Lom
#
#       actor_1_facebook_likes  gross                        genres  \
# 2702                   443.0    NaN  Drama|Fantasy|Mystery|Sci-Fi
# 3130                  1000.0    NaN        Horror|Sci-Fi|Thriller
#
#             actor_1_name    movie_title  num_voted_users  \
# 2702  David Ogden Stiers  The Dead Zone             7122
# 3130        Tom Skerritt  The Dead Zone            44804
#
#       cast_total_facebook_likes   actor_3_name  facenumber_in_poster  \
# 2702                        981    Chris Bruno                   1.0
# 3130                       2013  Anthony Zerbe                   0.0
#
#                                                       plot_keywords  \
# 2702  psychic|psychic power|psychometry|spin off|supernatural power
# 3130               car accident|coma|evil politician|psychic|vision
#
#                                            movie_imdb_link  \
# 2702  http://www.imdb.com/title/tt0281432/?ref_=fn_tt_tt_1
# 3130  http://www.imdb.com/title/tt0085407/?ref_=fn_tt_tt_1
#
#       num_user_for_reviews language country content_rating      budget  \
# 2702                  77.0  English  Canada          TV-14         NaN
# 3130                 182.0  English     USA              R  10000000.0
#
#       title_year  actor_2_facebook_likes  imdb_score  aspect_ratio  \
# 2702         NaN                   319.0         7.5           NaN
# 3130      1983.0                   278.0         7.2          1.85
#
#       movie_facebook_likes
# 2702                   576
# 3130                     0

# %%
#df_cp.index.unique()

# %% [markdown]
# #### remplacer Nan par strings

# %%
df_cp.head(1)
# Out:
#    color  director_name  num_critic_for_reviews  duration  \
# 0  Color  James Cameron                   723.0     178.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
#
#   actor_1_name movie_title  num_voted_users  cast_total_facebook_likes  \
# 0  CCH Pounder      Avatar           886204                       4834
#
#   actor_3_name  facenumber_in_poster                           plot_keywords  \
# 0    Wes Studi                   0.0  avatar|future|marine|native|paraplegic
#
#                                         movie_imdb_link  num_user_for_reviews  \
# 0  http://www.imdb.com/title/tt0499549/?ref_=fn_tt_tt_1                3054.0
#
#   language country content_rating       budget  title_year  \
# 0  English     USA          PG-13  237000000.0      2009.0
#
#    actor_2_facebook_likes  imdb_score  aspect_ratio  movie_facebook_likes
# 0                   936.0         7.9          1.78                 33000

# %%
# fill string type columns in with Unknown/Unrated if it is Null for 3NF
# at the end we will not use unknown words for ai
df_cp = df_cp.fillna({'color':'Unknown', 
           'director_name':'Unknown', 
           'actor_2_name':'Unknown', 
           'genres':'Unknown',
           'actor_1_name':'Unknown', 
           'actor_3_name':'Unknown', 
           'plot_keywords':'Unknown', 
           'movie_imdb_link':'Unknown',
           'language':'Unknown',
           'country': 'Unknown',
           'content_rating':'Unrated'
          })

# %%
df_cp[df_cp['director_name'] == 'Unknown'].head(2)
# Out:
#      color director_name  num_critic_for_reviews  duration  \
# 177  Color       Unknown                    21.0      60.0
# 260  Color       Unknown                    29.0      60.0
#
#      director_facebook_likes  actor_3_facebook_likes           actor_2_name  \
# 177                      NaN                   184.0  Philip Michael Thomas
# 260                      NaN                   432.0          Dirk Benedict
#
#      actor_1_facebook_likes  gross                               genres  \
# 177                   982.0    NaN  Action|Crime|Drama|Mystery|Thriller
# 260                   669.0    NaN               Action|Adventure|Crime
#
#        actor_1_name movie_title  num_voted_users  cast_total_facebook_likes  \
# 177     Don Johnson  Miami Vice            16769                       1687
# 260  George Peppard  The A-Team            25402                       1655
#
#        actor_3_name  facenumber_in_poster  \
# 177      John Diehl                   2.0
# 260  Dwight Schultz                   4.0
#
#                                                          plot_keywords  \
# 177                          cult tv|detective|drugs|police|undercover
# 260  1980s|cult tv|famous opening theme|good versus evil|hero for hire
#
#                                           movie_imdb_link  \
# 177  http://www.imdb.com/title/tt0086759/?ref_=fn_tt_tt_1
# 260  http://www.imdb.com/title/tt0084967/?ref_=fn_tt_tt_1
#
#      num_user_for_reviews language country content_rating     budget  \
# 177                  74.0  English     USA          TV-14  1500000.0
# 260                  97.0  English     USA          TV-PG        NaN
#
#      title_year  actor_2_facebook_likes  imdb_score  aspect_ratio  \
# 177         NaN                   321.0         7.5          1.33
# 260         NaN                   554.0         7.6          4.00
#
#      movie_facebook_likes
# 177                     0
# 260                     0

# %%
# fill numeric (int, float) type columns in with -1 if it is Null
df_cp = df_cp.fillna({'num_critic_for_reviews':-1, 
           'duration':-1, 
           'director_facebook_likes':-1, 
           'actor_3_facebook_likes':-1, 
           'actor_1_facebook_likes':-1, 
           'gross':-1,
           'num_voted_users':-1,
           'cast_total_facebook_likes':-1,
           'facenumber_in_poster':-1,
           'num_user_for_reviews':-1,
           'budget':-1,
           'title_year':-1,
           'actor_2_facebook_likes':-1,
           'imdb_score':-1,
           'aspect_ratio':-1,
           'movie_facebook_likes':-1
          })

#df_cp = df_cp.fillna(-1)

# %%
df_cp.isnull().sum()
# Out:
# color                        0
# director_name                0
# num_critic_for_reviews       0
# duration                     0
# director_facebook_likes      0
# actor_3_facebook_likes       0
# actor_2_name                 0
# actor_1_facebook_likes       0
# gross                        0
# genres                       0
# actor_1_name                 0
# movie_title                  0
# num_voted_users              0
# cast_total_facebook_likes    0
# actor_3_name                 0
# facenumber_in_poster         0
# plot_keywords                0
# movie_imdb_link              0
# num_user_for_reviews         0
# language                     0
# country                      0
# content_rating               0
# budget                       0
# title_year                   0
# actor_2_facebook_likes       0
# imdb_score                   0
# aspect_ratio                 0
# movie_facebook_likes         0
# dtype: int64

# %%
df_cp.shape
# Out:
# (4919, 28)

# %%
# change title_year type to int
df_cp['title_year'] = df_cp['title_year'].astype(int)

# %%
#export to csv
df_cp.to_csv('movie.csv', index = False)

# %% [markdown]
# #### prepare director csv

# %%
director = df_cp['director_name'].unique()

# %%
director
# Out:
# array(['James Cameron', 'Gore Verbinski', 'Sam Mendes', ...,
#        'Scott Smith', 'Benjamin Roberds', 'Daniel Hsia'], dtype=object)

# %%
df_director = pd.DataFrame(director, columns=['director_name'])

# %%
#export to csv
df_director.to_csv('df_director.csv', index = False)

# %% [markdown]
# #### Je vais spliter director_name to first_name and last_name

# %%
df_director_split = df_director.copy()

# %%
for i in range(1,10,1):
    print(df_director.loc[df_director['director_name'].str.split().str.len() == i])
# Out:
#      director_name
# 30             McG
# 106        Unknown
# 171          Pitof
# 462   Costa-Gavras
# 1114           RZA
# 1409       Maïwenn
# 1667        Shekar
# 1947          Remo
# 2333     Valentine
#           director_name
# 0         James Cameron
# 1        Gore Verbinski
# 2            Sam Mendes
# 3     Christopher Nolan
# 4           Doug Walker
# ...                 ...
# 2393      Shane Carruth
# 2395    Anthony Vallone
# 2396        Scott Smith
# 2397   Benjamin Roberds
# 2398        Daniel Hsia
#
# [2182 rows x 1 columns]
#                   director_name
# 34           Guillermo del Toro
# 88          Jennifer Yuh Nelson
# 1184            Preston A. Whitmore II
# 1192          Daisy von Scherler Mayer
# 1318  Florian Henckel von Donnersmarck
# 1362                Álex de la Iglesia
# 1671              Analeine Cal y Mayor
# 1722           Fernando León de Aranoa
# 2051             Regardt van den Bergh
# Empty DataFrame
# Columns: [director_name]
# Index: []
# Empty DataFrame
# Columns: [director_name]
# Index: []
# Empty DataFrame
# Columns: [director_name]
# Index: []
# Empty DataFrame
# Columns: [director_name]
# Index: []
# Empty DataFrame
# Columns: [director_name]
# Index: []

# %%
df_director_split.iloc[610:620]
# Out:
#            director_name
# 610   Patrick Tatopoulos
# 611  Gary David Goldberg
# 612            Alan Poul
# 613      Luke Greenfield
# 614           Gil Junger
# 615      Michael Ritchie
# 616   Steven E. de Souza
# 617        Alexandre Aja
# 618        Michael Rymer
# 619          Hugh Wilson

# %%
df_director_split.loc[df_director_split['director_name'].str.split().str.len() == 1, 'first_name'] = df_director_split['director_name'].str.split().str[0]
df_director_split.loc[df_director_split['director_name'].str.split().str.len() == 1, 'last_name'] = df_director_split['director_name'].str.split().str[-1]

# %%
# split director_name into last_name and first_name if director_name composed only 2 names
df_director_split.loc[df_director_split['director_name'].str.split().str.len() == 2, 'first_name'] = df_director_split['director_name'].str.split().str[0]
df_director_split.loc[df_director_split['director_name'].str.split().str.len() == 2, 'last_name'] = df_director_split['director_name'].str.split().str[-1]

# %%
df_director_split.loc[df_director_split['director_name'].str.split().str.len() == 3, 'first_name'] = df_director_split['director_name'].str.split().str[0]
df_director_split.loc[df_director_split['director_name'].str.split().str.len() == 3, 'last_name'] = df_director_split['director_name'].str.split().str[-2] + ' ' + df_director_split['director_name'].str.split().str[-1]

# %%
df_director_split.loc[df_director_split['director_name'].str.split().str.len() == 4, 'first_name'] = df_director_split['director_name'].str.split().str[0]
df_director_split.loc[df_director_split['director_name'].str.split().str.len() == 4, 'last_name'] = df_director_split['director_name'].str.split().str[-3] + ' ' + df_director_split['director_name'].str.split().str[-2] + ' ' + df_director_split['director_name'].str.split().str[-1]

# %%
df_director_split.loc[df_director_split['director_name'].str.split().str.len() == 4]
# Out:
#                          director_name first_name                 last_name
# 616                 Steven E. de Souza     Steven               E. de Souza
# 1184            Preston A. Whitmore II    Preston            A. Whitmore II
# 1192          Daisy von Scherler Mayer      Daisy        von Scherler Mayer
# 1318  Florian Henckel von Donnersmarck    Florian  Henckel von Donnersmarck
# 1362                Álex de la Iglesia       Álex             de la Iglesia
# 1671              Analeine Cal y Mayor   Analeine               Cal y Mayor
# 1722           Fernando León de Aranoa   Fernando            León de Aranoa
# 2051             Regardt van den Bergh    Regardt             van den Bergh

# %%
df_director_split.shape
# Out:
# (2399, 3)

# %%
#export to csv
df_director_split.to_csv('df_director_split.csv', index = False)

# %% [markdown]
# #### prepare actor.csv

# %%
from itertools import chain

df_actor123 = df_cp[['actor_1_name','actor_2_name','actor_3_name']]
actor_unique = list(set(chain.from_iterable(df_actor123.values)))
df_actor = pd.DataFrame(actor_unique, columns=['actor_name'])

# %%
df_actor.nunique()
# Out:
# actor_name    6256
# dtype: int64

# %%
#export to csv
df_actor.to_csv('df_actor.csv', index = False)

# %% [markdown]
# #### Je vais spliter actor_name to first_name and last_name

# %%
df_actor_split = df_actor.copy()

# %%
for i in range(1,10,1):
    print(df_actor.loc[df_actor['actor_name'].str.split().str.len() == i])
# Out:
#             actor_name
# 20                Akon
# 21        Brahmanandam
# 676        Ann-Margret
# 749               T.I.
# 909              Bhama
# 978               Pelé
# 1094           Steve-O
# 1206           Lalaine
# 1226       Prabhudheva
# 1291           Maïwenn
# 1343            Divine
# 1415             Ice-T
# 1517           Revathy
# 1572              Flea
# 1731              Mako
# 1899              Bono
# 2106           Charice
# 2167           Luenell
# 2280               Eve
# 2571           Chester
# 2944          Mo'Nique
# 3020            Xzibit
# 3065              Leon
# 3088              Remo
# 3106             Slash
# 3129            Denden
# 3172            Common
# 3314             Akima
# 3434             Topol
# 3565           Aaliyah
# 3724             Rekha
# 3835             Terry
# 3868           Prabhas
# 4020       Laura-Leigh
# 4035              Pink
# 4037            Malika
# 4054          Madhavan
# 4201             Lemmy
# 4207              Rain
# 4235           Prateik
# 4243         Will.i.am
# 4401             Björk
# 4526             Drake
# 4529         Valentine
# 4811  Circus-Szalewski
# 4902      Raven-Symoné
# 4919            Fergie
# 4989            Vanity
# 4998              Tabu
# 5376           Diganth
# 5559               DMX
# 5601              Lucy
# 5638           Unknown
# 5799           Ashanti
# 6018            Amidou
# 6094              Asin
# 6195         Matisyahu
# 6221               RZA
#              actor_name
# 0       Michael Chapman
# 1         Martin Sharpe
# 2     Jordan Trovillion
# 3           Akie Kotabe
# 4     Kamatari Fujiwara
# ...                 ...
# 6251       Yayan Ruhian
# 6252         Ivan Dixon
# 6253    Fernanda Torres
# 6254       Kang-ho Song
# 6255  Isaiah Washington
#
# [5714 rows x 1 columns]
#                          actor_name
# 36                     Doug E. Doug
# 56             Nora von Waldstätten
# 73               Sammy Nagi Njuguna
# 74             Siobhan Fallon Hogan
# 75                   D. David Morin
# 105                     Boys II Men
# 126               Kimberly J. Brown
# 130              Brandon T. Jackson
# 138            Jennifer Lee Wiggins
# 145           Sandra Ellis Lafferty
# 158            Brandon Mychal Smith
# 159                  Luis E. Carazo
# 167               F. Murray Abraham
# 180                 Pant Shirt Baba
# 185                 Scott A. Martin
# 214              Tonya Lee Williams
# 230         Mary Catherine Garrison
# 272        Natalie Stephany Aguilar
# 306             S. Epatha Merkerson
# 308           Amber Marie Bollinger
# 316                 Keri Lynn Pratt
# 319          Chris 'Wonder' Schoeck
# 320            Mohamad Haref Harati
# 337              Mohammad Amir Naji
# 358          Anthony Chau-Sang Wong
# 373          Natasha Gregson Wagner
# 390            Riley Thomas Stewart
# 462           Eddie 'Piolin' Sotelo
# 467                 Sammy Davis Jr.
# 477                 George C. Scott
# 519           Christopher B. Duncan
# 522                 Julie Dawn Cole
# 537               Julia Taylor Ross
# 538           Gregory Scott Cummins
# 540           Kathleen Rose Perkins
# 551                 Jessica De Gouw
# 553            John Michael Higgins
# 559          Peter Youngblood Hills
# 562               Mary Lynn Rajskub
# 567                  Joey D. Vieira
# 580                  Shah Rukh Khan
# 593                Thomas Bo Larsen
# 634        Christopher Robin Miller
# 653          Athina Rachel Tsangari
# 659               Nicole Ari Parker
# 672                  Rae Dawn Chong
# 687                 Eva Marie Saint
# 691               Haley Joel Osment
# 696            Alexandra Maria Lara
# 697                  John de Lancie
# 707             Derek Wayne Johnson
# 716                   Brad Lee Wind
# 5757                 Lon Chaney Jr.
# 5768                 Joe Lo Truglio
# 5779       Bianca Brigitte VanDamme
# 5796           Jonathan Morgan Heit
# 5813            David Adam Flannery
# 5819             Patrick St. Esprit
# 5834            Penelope Ann Miller
# 5839                 Kari J. Kramer
# 5846           Roger Guenveur Smith
# 5849           Stig Frode Henriksen
# 5857             Eva Amurri Martino
# 5858           Tyler James Williams
# 5860             Gian Maria Volontè
# 5869               David Alan Grier
# 5882          Skye McCole Bartusiak
# 5883            Serena Scott Thomas
# 5894                John F. Kennedy
# 5898            Darren Keefe Reiher
# 5899            Joseph Julian Soria
# 5915              Jean Louisa Kelly
# 5917              Erik Per Sullivan
# 5952                  James Le Gros
# 5964                 Hal Landon Jr.
# 5967             S. William Hinzman
# 5972               Tim Blake Nelson
# 5976             Robin Atkin Downes
# 5982               Joel David Moore
# 5994              Miguel Ángel Solá
# 6042             Toby Leonard Moore
# 6044          Zackary Steven Graham
# 6046                 Isild Le Besco
# 6060              Andrea Di Stefano
# 6064              Mario Van Peebles
# 6065                  Mary J. Blige
# 6101               Paula Jai Parker
# 6127         Misha Gabriel Hamilton
# 6133              Bonnie Lee Bouman
# 6167                  Chi Chung Lam
# 6178                Jesse L. Martin
# 6240                      Li Jun Li
#                         actor_name
# 422         William Joseph Elk III
# 543          Anneliese van der Pol
# 724     Tulku Jamyang Kunga Tenzin
# 1111        Mike 'The Miz' Mizanin
# 1261          Benjamin J. Cain Jr.
# 1340     José Manuel Orozco Angulo
# 1431           Miguel A. Núñez Jr.
# 1947  Balinese Tari Legong Dancers
# 2402              Paz de la Huerta
# 2583             Ana de la Reguera
# 2588           Tony Chiu Wai Leung
# 2879           Larry the Cable Guy
# 4168        Isaac C. Singleton Jr.
# 4181     Paul 'Pauly D' DelVecchio
# 4503         Cristián de la Fuente
# 4673           Rodrigo De la Serna
# 4759          Puti Sri Candra Dewi
# 5107        Collin Alfredo St. Dic
# 5298           Antonio de la Torre
# Empty DataFrame
# Columns: [actor_name]
# Index: []
# Empty DataFrame
# Columns: [actor_name]
# Index: []
# Empty DataFrame
# Columns: [actor_name]
# Index: []
# Empty DataFrame
# Columns: [actor_name]
# Index: []
# Empty DataFrame
# Columns: [actor_name]
# Index: []

# %%
df_actor_split.loc[df_actor_split['actor_name'].str.split().str.len() == 1]
# Out:
#             actor_name
# 20                Akon
# 21        Brahmanandam
# 676        Ann-Margret
# 749               T.I.
# 909              Bhama
# 978               Pelé
# 1094           Steve-O
# 1206           Lalaine
# 1226       Prabhudheva
# 1291           Maïwenn
# 1343            Divine
# 1415             Ice-T
# 1517           Revathy
# 1572              Flea
# 1731              Mako
# 1899              Bono
# 2106           Charice
# 2167           Luenell
# 2280               Eve
# 2571           Chester
# 2944          Mo'Nique
# 3020            Xzibit
# 3065              Leon
# 3088              Remo
# 3106             Slash
# 3129            Denden
# 3172            Common
# 3314             Akima
# 3434             Topol
# 3565           Aaliyah
# 3724             Rekha
# 3835             Terry
# 3868           Prabhas
# 4020       Laura-Leigh
# 4035              Pink
# 4037            Malika
# 4054          Madhavan
# 4201             Lemmy
# 4207              Rain
# 4235           Prateik
# 4243         Will.i.am
# 4401             Björk
# 4526             Drake
# 4529         Valentine
# 4811  Circus-Szalewski
# 4902      Raven-Symoné
# 4919            Fergie
# 4989            Vanity
# 4998              Tabu
# 5376           Diganth
# 5559               DMX
# 5601              Lucy
# 5638           Unknown
# 5799           Ashanti
# 6018            Amidou
# 6094              Asin
# 6195         Matisyahu
# 6221               RZA

# %%
df_actor_split
# Out:
#              actor_name
# 0       Michael Chapman
# 1         Martin Sharpe
# 2     Jordan Trovillion
# 3           Akie Kotabe
# 4     Kamatari Fujiwara
# ...                 ...
# 6251       Yayan Ruhian
# 6252         Ivan Dixon
# 6253    Fernanda Torres
# 6254       Kang-ho Song
# 6255  Isaiah Washington
#
# [6256 rows x 1 columns]

# %%
df_actor_split.isnull().sum()
# Out:
# actor_name    0
# dtype: int64

# %%
df_actor_split.loc[df_actor_split['actor_name'].str.split().str.len() == 1, 'first_name'] = df_actor_split['actor_name'].str.split().str[0]
df_actor_split.loc[df_actor_split['actor_name'].str.split().str.len() == 1, 'last_name'] = df_actor_split['actor_name'].str.split().str[0]

# %%
df_actor_split.loc[df_actor_split['actor_name'].str.split().str.len() == 2, 'first_name'] = df_actor_split['actor_name'].str.split().str[-2]
df_actor_split.loc[df_actor_split['actor_name'].str.split().str.len() == 2, 'last_name'] = df_actor_split['actor_name'].str.split().str[-1]

# %%
df_actor_split.loc[df_actor_split['actor_name'].str.split().str.len() == 3, 'first_name'] = df_actor_split['actor_name'].str.split().str[0]
df_actor_split.loc[df_actor_split['actor_name'].str.split().str.len() == 3, 'last_name'] = df_actor_split['actor_name'].str.split().str[-2] + ' ' + df_actor_split['actor_name'].str.split().str[-1]

# %%
df_actor_split.loc[df_actor_split['actor_name'].str.split().str.len() == 4, 'first_name'] = df_actor_split['actor_name'].str.split().str[0]
df_actor_split.loc[df_actor_split['actor_name'].str.split().str.len() == 4, 'last_name'] = df_actor_split['actor_name'].str.split().str[-3] + ' ' + df_actor_split['actor_name'].str.split().str[-2] + ' ' + df_actor_split['actor_name'].str.split().str[-1]

# %%
df_actor_split.isnull().sum()
# Out:
# actor_name    0
# first_name    0
# last_name     0
# dtype: int64

# %%
#export to csv
df_actor_split.to_csv('df_actor_split.csv', index = False)

# %% [markdown]
# #### prepare genres.csv

# %%
df_cp['genres'].value_counts()
# Out:
# Drama                                                     233
# Comedy                                                    205
# Comedy|Drama                                              189
# Comedy|Drama|Romance                                      185
# Comedy|Romance                                            157
#                                                          ...
# Crime|Drama|History                                         1
# Action|Animation|Comedy|Family|Fantasy|Sci-Fi               1
# Biography|Crime|Drama|History|Thriller                      1
# Adventure|Animation|Comedy|Drama|Family|Fantasy|Sci-Fi      1
# Comedy|Crime|Horror                                         1
# Name: genres, Length: 914, dtype: int64

# %%
genres = df_cp['genres'].unique()

# %%
df_genres= pd.DataFrame(genres, columns=['genres'])

# %%
# separate genre with | and then stack them
stacked = pd.DataFrame(df_genres.genres.str.split(pat='|').tolist()).stack()

# %%
stacked
# Out:
# 0    0       Action
#      1    Adventure
#      2      Fantasy
#      3       Sci-Fi
# 1    0       Action
#             ...
# 912  1        Drama
#      2       Horror
# 913  0       Comedy
#      1        Crime
#      2       Horror
# Length: 3569, dtype: object

# %%
genres = pd.DataFrame(stacked.value_counts().index.to_list(), columns = ["genres"])

# %%
genres = genres.sort_values(by="genres", inplace=False, ignore_index=True)

# %%
genres.to_csv('genres.csv', index = False)
